# %%
import numpy as np
import pandas as pd

# %%
dict1={
    'name':['harry','rohan','skillf','shubh'],
    'marks':[92,34,24,17],
    'city':['rampur','kolkata','bareilly','antarctica']
}

# %%
dict1
# Out:
# {'name': ['harry', 'rohan', 'skillf', 'shubh'],
#  'marks': [92, 34, 24, 17],
#  'city': ['rampur', 'kolkata', 'bareilly', 'antarctica']}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     34     kolkata
# 2  skillf     24    bareilly
# 3   shubh     17  antarctica

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index_false.csv', index=False)

# %%
df.head(2) #starting rows
# Out:
#     name  marks     city
# 0  harry     92   rampur
# 1  rohan     34  kolkata

# %%
df.tail(2) #ending rows
# Out:
#      name  marks        city
# 2  skillf     24    bareilly
# 3   shubh     17  antarctica

# %%
df.describe()
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
df.to_csv('harry.csv',index=False)

# %%
harry=pd.read_csv('harry.csv')

# %%
harry
# Out:
#    Train No  Speed        city
# 0     12322     34      rampur
# 1     12534    123     kolkata
# 2    125654     67    bareilly
# 3    564523     87  antarctica

# %%
harry['Speed']
# Out:
# 0     34
# 1    123
# 2     67
# 3     87
# Name: Speed, dtype: int64

# %%
harry['Speed'][0]
# Out:
# 34

# %%
harry['Speed'][0]=50
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
harry
# Out:
#    Train No  Speed        city
# 0     12322     50      rampur
# 1     12534    123     kolkata
# 2    125654     67    bareilly
# 3    564523     87  antarctica

# %%
harry.to_csv('harry.csv', index=False)

# %%
harry.index=['first','second','third','fourth']

# %%
harry
# Out:
#         Train No  Speed        city
# first      12322     50      rampur
# second     12534    123     kolkata
# third     125654     67    bareilly
# fourth    564523     87  antarctica

# %%
ser=pd.Series(np.random.randn(34))

# %%
ser
# Out:
# 0     0.551594
# 1     0.478361
# 2     0.422991
# 3     0.203047
# 4    -0.071774
# 5    -0.595130
# 6    -0.677080
# 7     0.384195
# 8    -0.483051
# 9    -0.336386
# 10   -1.884840
# 11    0.185285
# 12   -0.043400
# 13    1.083066
# 14    1.180698
# 15    1.175084
# 16    1.524941
# 17   -0.393383
# 18    0.811201
# 19   -1.066997
# 20   -0.111138
# 21    0.263090
# 22    0.922396
# 23   -0.108864
# 24    0.394450
# 25    0.061500
# 26    0.362560
# 27    1.534955
# 28    1.536405
# 29    0.816109
# 30    0.946758
# 31   -0.120123
# 32   -1.337916
# 33    0.788675
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf=pd.DataFrame(np.random.randn(334,5),index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0   -0.985972  0.399841 -0.186752  0.149737 -0.124718
# 1    0.892176  1.544940  0.396532  0.657482  1.888783
# 2   -1.077771 -1.858565 -1.181664  0.085732  1.108963
# 3   -0.094873  0.023738  0.409826 -0.596839  1.762689
# 4   -0.460195 -0.686177  0.521803 -1.386710 -0.419500
# ..        ...       ...       ...       ...       ...
# 329  0.310471 -0.659180  0.522635 -0.275018 -0.257088
# 330 -0.891386 -0.121718  0.409970  1.112106  1.939046
# 331  0.587337 -0.679106 -0.804315  1.157552 -0.305324
# 332  0.058244 -0.351281 -0.125534  0.062318  1.078857
# 333  0.727152 -0.218460  1.020523  1.120779 -0.142830
#
# [334 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0 -0.985972  0.399841 -0.186752  0.149737 -0.124718
# 1  0.892176  1.544940  0.396532  0.657482  1.888783
# 2 -1.077771 -1.858565 -1.181664  0.085732  1.108963
# 3 -0.094873  0.023738  0.409826 -0.596839  1.762689
# 4 -0.460195 -0.686177  0.521803 -1.386710 -0.419500

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean    -0.021819    0.046626    0.044572   -0.046765    0.016761
# std      1.036649    0.991830    0.957978    1.024871    1.006820
# min     -2.587965   -2.681297   -2.474845   -2.842335   -2.952884
# 25%     -0.758362   -0.620034   -0.597404   -0.672649   -0.574060
# 50%     -0.037958    0.018990   -0.003937   -0.062468    0.060630
# 75%      0.671192    0.754623    0.688770    0.653480    0.642350
# max      3.049170    2.898806    2.630142    2.615807    2.392971

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf[0][0]
columns]

# %%
newdf.drop(['A','C'],axis=1)
# Out:
#             B         D         E
# 0    0.399841  0.149737 -0.124718
# 1    1.544940  0.657482  1.888783
# 2   -1.858565  0.085732  1.108963
# 3    0.023738 -0.596839  1.762689
# 4   -0.686177 -1.386710 -0.419500
# ..        ...       ...       ...
# 329 -0.659180 -0.275018 -0.257088
# 330 -0.121718  1.112106  1.939046
# 331 -0.679106  1.157552 -0.305324
# 332 -0.351281  0.062318  1.078857
# 333 -0.218460  1.120779 -0.142830
#
# [334 rows x 3 columns]

# %%
newdf.drop(['A','D'],axis=1)
# Out:
#             B         C         E
# 0    0.399841 -0.186752 -0.124718
# 1    1.544940  0.396532  1.888783
# 2   -1.858565 -1.181664  1.108963
# 3    0.023738  0.409826  1.762689
# 4   -0.686177  0.521803 -0.419500
# ..        ...       ...       ...
# 329 -0.659180  0.522635 -0.257088
# 330 -0.121718  0.409970  1.939046
# 331 -0.679106 -0.804315 -0.305324
# 332 -0.351281 -0.125534  1.078857
# 333 -0.218460  1.020523 -0.142830
#
# [334 rows x 3 columns]

# %%
newdf
# Out:
#             B         D         E
# 0    0.399841  0.149737 -0.124718
# 1    1.544940  0.657482  1.888783
# 2   -1.858565  0.085732  1.108963
# 3    0.023738 -0.596839  1.762689
# 4   -0.686177 -1.386710 -0.419500
# ..        ...       ...       ...
# 329 -0.659180 -0.275018 -0.257088
# 330 -0.121718  1.112106  1.939046
# 331 -0.679106  1.157552 -0.305324
# 332 -0.351281  0.062318  1.078857
# 333 -0.218460  1.120779 -0.142830
#
# [334 rows x 3 columns]

# %%
newdf.drop([1,5],axis=0,inplace=True)

# %%
newdf
# Out:
#             B         D         E
# 0    0.399841  0.149737 -0.124718
# 2   -1.858565  0.085732  1.108963
# 3    0.023738 -0.596839  1.762689
# 4   -0.686177 -1.386710 -0.419500
# 6   -0.374227  2.161585  0.534266
# ..        ...       ...       ...
# 329 -0.659180 -0.275018 -0.257088
# 330 -0.121718  1.112106  1.939046
# 331 -0.679106  1.157552 -0.305324
# 332 -0.351281  0.062318  1.078857
# 333 -0.218460  1.120779 -0.142830
#
# [332 rows x 3 columns]

# %%
newdf.head(3)
# Out:
#           B         D         E
# 0  0.399841  0.149737 -0.124718
# 2 -1.858565  0.085732  1.108963
# 3  0.023738 -0.596839  1.762689

# %%
newdf.reset_index()
# Out:
#      index         B         D         E
# 0        0  0.399841  0.149737 -0.124718
# 1        2 -1.858565  0.085732  1.108963
# 2        3  0.023738 -0.596839  1.762689
# 3        4 -0.686177 -1.386710 -0.419500
# 4        6 -0.374227  2.161585  0.534266
# ..     ...       ...       ...       ...
# 327    329 -0.659180 -0.275018 -0.257088
# 328    330 -0.121718  1.112106  1.939046
# 329    331 -0.679106  1.157552 -0.305324
# 330    332 -0.351281  0.062318  1.078857
# 331    333 -0.218460  1.120779 -0.142830
#
# [332 rows x 4 columns]

# %%
newdf.reset_index(drop=True)
# Out:
#             B         D         E
# 0    0.399841  0.149737 -0.124718
# 1   -1.858565  0.085732  1.108963
# 2    0.023738 -0.596839  1.762689
# 3   -0.686177 -1.386710 -0.419500
# 4   -0.374227  2.161585  0.534266
# ..        ...       ...       ...
# 327 -0.659180 -0.275018 -0.257088
# 328 -0.121718  1.112106  1.939046
# 329 -0.679106  1.157552 -0.305324
# 330 -0.351281  0.062318  1.078857
# 331 -0.218460  1.120779 -0.142830
#
# [332 rows x 3 columns]

# %%
newdf.reset_index(drop=True, inplace=True)

# %%
newdf
# Out:
#             B         D         E
# 0    0.399841  0.149737 -0.124718
# 1   -1.858565  0.085732  1.108963
# 2    0.023738 -0.596839  1.762689
# 3   -0.686177 -1.386710 -0.419500
# 4   -0.374227  2.161585  0.534266
# ..        ...       ...       ...
# 327 -0.659180 -0.275018 -0.257088
# 328 -0.121718  1.112106  1.939046
# 329 -0.679106  1.157552 -0.305324
# 330 -0.351281  0.062318  1.078857
# 331 -0.218460  1.120779 -0.142830
#
# [332 rows x 3 columns]

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: B, Length: 332, dtype: bool

# %%
newdf['B']=None

# %%
newdf
# Out:
#         B         D         E
# 0    None  0.149737 -0.124718
# 1    None  0.085732  1.108963
# 2    None -0.596839  1.762689
# 3    None -1.386710 -0.419500
# 4    None  2.161585  0.534266
# ..    ...       ...       ...
# 327  None -0.275018 -0.257088
# 328  None  1.112106  1.939046
# 329  None  1.157552 -0.305324
# 330  None  0.062318  1.078857
# 331  None  1.120779 -0.142830
#
# [332 rows x 3 columns]

# %%
newdf['B'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 327    True
# 328    True
# 329    True
# 330    True
# 331    True
# Name: B, Length: 332, dtype: bool

# %%
newdf.loc[:,['B']]=56

# %%
newdf
# Out:
#       B         D         E
# 0    56  0.149737 -0.124718
# 1    56  0.085732  1.108963
# 2    56 -0.596839  1.762689
# 3    56 -1.386710 -0.419500
# 4    56  2.161585  0.534266
# ..   ..       ...       ...
# 327  56 -0.275018 -0.257088
# 328  56  1.112106  1.939046
# 329  56  1.157552 -0.305324
# 330  56  0.062318  1.078857
# 331  56  1.120779 -0.142830
#
# [332 rows x 3 columns]

# %%
df=pd.DataFrame({
    "name":['Alfred','Batman','Alfred'],
    "toy":[np.nan,'Batmobile','Bullwhip'],
    "born":[pd.NaT, pd.Timestamp("1940-04-25"),pd.NaT]
})

# %%
df
# Out:
#      name        toy       born
# 0  Alfred        NaN        NaT
# 1  Batman  Batmobile 1940-04-25
# 2  Alfred   Bullwhip        NaT

# %%
df.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(how='all')
# Out:
#        name  toy       born
# 0    Alfred  NaN        NaT
# 1    Batman  NaN 1940-04-25
# 2  Catwoman  NaN        NaT

# %%
df.dropna(how='all',axis=1)
# Out:
#        name       born
# 0    Alfred        NaT
# 1    Batman 1940-04-25
# 2  Catwoman        NaT

# %%
df.drop_duplicates(subset=['name'], keep='first')
# Out:
#      name        toy       born
# 0  Alfred        NaN        NaT
# 1  Batman  Batmobile 1940-04-25

# %%
df.drop_duplicates(subset=['name'], keep='last')
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25
# 2  Alfred   Bullwhip        NaT

# %%
df.drop_duplicates(subset=['name'], keep=False)
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
# name    3 non-null object
# toy     2 non-null object
# born    1 non-null datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 200.0+ bytes

# %%
df.describe()
# Out:
#           name       toy                 born
# count        3         2                    1
# unique       2         2                    1
# top     Alfred  Bullwhip  1940-04-25 00:00:00
# freq         2         1                    1
# first      NaN       NaN  1940-04-25 00:00:00
# last       NaN       NaN  1940-04-25 00:00:00

# %%
df['name'].value_counts(dropna=False)
# Out:
# Alfred    2
# Batman    1
# Name: name, dtype: int64

# %%
df['toy'].value_counts(dropna=False)
# Out:
# Bullwhip     1
# Batmobile    1
# Name: toy, dtype: int64

# %%
df['toy'].value_counts(dropna=True)
# Out:
# Bullwhip     1
# Batmobile    1
# Name: toy, dtype: int64

# %%
df.notnull()
# Out:
#    name    toy   born
# 0  True  False  False
# 1  True   True   True
# 2  True   True  False

# %%
DF=pd.DataFrame(np.random.randn(3,2), index=np.arange(3))

# %%
DF
# Out:
#           0         1
# 0  1.407356 -1.949631
# 1  0.772914 -0.198099
# 2  0.609506 -0.125567

# %%
DF.describe()
# Out:
#               0         1
# count  3.000000  3.000000
# mean   0.929925 -0.757766
# std    0.421463  1.032822
# min    0.609506 -1.949631
# 25%    0.691210 -1.073865
# 50%    0.772914 -0.198099
# 75%    1.090135 -0.161833
# max    1.407356 -0.125567

# %%
DF.mean()
# Out:
# 0    0.929925
# 1   -0.757766
# dtype: float64

# %%
DF.corr()
# Out:
#           0         1
# 0  1.000000 -0.987232
# 1 -0.987232  1.000000

# %%
DF.count()
# Out:
# 0    3
# 1    3
# dtype: int64

# %%
DF.max()
# Out:
# 0    1.407356
# 1   -0.125567
# dtype: float64

# %%
DF.min()
# Out:
# 0    0.609506
# 1   -1.949631
# dtype: float64

# %%
DF.median()
# Out:
# 0    0.772914
# 1   -0.198099
# dtype: float64

# %%
DF.std()
# Out:
# 0    0.421463
# 1    1.032822
# dtype: float64

# %%
data=pd.read_excel('data.xlsx')

# %%
data
# Out:
#    Train No2  Speed2       city2
# 0      12322      50      rampur
# 1      12534     123     kolkata
# 2     125654      54    bareilly
# 3     564523      41  antarctica

# %%
data.iloc[0,0]=34

# %%
data
# Out:
#    Train No2  Speed2       city2
# 0         34      50      rampur
# 1      12534     123     kolkata
# 2     125654      54    bareilly
# 3     564523      41  antarctica
